# %% [markdown]
# <a href="https://colab.research.google.com/github/py242016019/CEE2/blob/main/18_exerc%C3%ADcio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Distribuição Binomial
#
# A **distribuição Binomial** é uma distribuição de probabilidade discreta que modela o número de sucessos em $n$ ensaios independentes de Bernoulli(
# $p$).
#
# ##Definições e Propriedades
#
# + Notação:
# $$X \sim Binomial(n,p)$$
#
# + Função de probabilidade:
# $$P[X=k]= {n \choose k}{p^k}{(1-p)^{n-k}}, k= 0,1,2,...,n.$$
#
# + Valor esperado:
# $$E[X]= np$$
#
# + Variância:
# $$Var[X]= np(1-p)$$
#
# ### Gráfico da distribuição
#
# Abaixo apresentamos o gráfico da função de probabilidade da distribuição binomial com $n=10$ e $p=0.3$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parâmetros da distribuição
n = 10  # Número de experimentos
p = 0.3  # Probabilidade de sucesso

# Valores possíveis de X
x = np.arange(0, n+1)

# Função de probabilidade
prob = binom.pmf(x, n, p)

# Plotar o gráfico
plt.figure(figsize=(4, 3))
plt.bar(x, prob, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Distribuição Binomial (n=10, p=0.3)', fontsize=14)
plt.xlabel('Número de sucessos (k)', fontsize=12)
plt.ylabel('P(X=k)', fontsize=12)
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
